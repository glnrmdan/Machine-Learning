# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# Sample dataset
plt.figure(figsize=(18, 8))

num_rows = 4
num_cols = 8

# plot each of the images in the batch and the associated ground truth labels.
for i in range(num_rows * num_cols):
    ax = plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(x_train[i, :, :])
    plt.axis("off")

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
# Build the model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(28, activation='relu'),
    Dropout(0.2),
    Dense(14, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=20, validation_split=0.2, batch_size=128)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.7677 - accuracy: 0.7536 - val_loss: 0.2868 - val_accuracy: 0.9241
# Epoch 2/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5037 - accuracy: 0.8528 - val_loss: 0.2766 - val_accuracy: 0.9254
# Epoch 3/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4608 - accuracy: 0.8665 - val_loss: 0.2502 - val_accuracy: 0.9343
# Epoch 4/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4388 - accuracy: 0.8710 - val_loss: 0.2490 - val_accuracy: 0.9351
# Epoch 5/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4300 - accuracy: 0.8741 - val_loss: 0.2598 - val_accuracy: 0.9365
# Epoch 6/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4184 - accuracy: 0.8802 - val_loss: 0.2366 - val_accuracy: 0.9391
# Epoch 7/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4046 - accuracy: 0.8841 - val_loss: 0.2469 - val_accuracy: 0.9402
# Epoch 8/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4076 - accuracy: 0.8817 - val_loss: 0.2448 - val_accuracy: 0.9399
# Epoch 9/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3876 - accuracy: 0.8878 - val_loss: 0.2454 - val_accuracy: 0.9407
# Epoch 10/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3868 - accuracy: 0.8884 - val_loss: 0.2358 - val_accuracy: 0.9442
# Epoch 11/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3815 - accuracy: 0.8898 - val_loss: 0.2475 - val_accuracy: 0.9377
# Epoch 12/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3892 - accuracy: 0.8887 - val_loss: 0.2450 - val_accuracy: 0.9375
# Epoch 13/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3775 - accuracy: 0.8908 - val_loss: 0.2334 - val_accuracy: 0.9417
# Epoch 14/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3725 - accuracy: 0.8919 - val_loss: 0.2297 - val_accuracy: 0.9407
# Epoch 15/20
# 375/375 [==============================] - 2s 7ms/step - loss: 0.3693 - accuracy: 0.8936 - val_loss: 0.2346 - val_accuracy: 0.9442
# Epoch 16/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3649 - accuracy: 0.8944 - val_loss: 0.2464 - val_accuracy: 0.9410
# Epoch 17/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3776 - accuracy: 0.8921 - val_loss: 0.2315 - val_accuracy: 0.9427
# Epoch 18/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3630 - accuracy: 0.8961 - val_loss: 0.2596 - val_accuracy: 0.9425
# Epoch 19/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3650 - accuracy: 0.8960 - val_loss: 0.2435 - val_accuracy: 0.9457
# Epoch 20/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3670 - accuracy: 0.8953 - val_loss: 0.2353 - val_accuracy: 0.9469

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.2419 - accuracy: 0.9397 - 610ms/epoch - 2ms/step

# %%
# Visualize the training results
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plot training & validation accuracy values
axs[0].plot(history.history['accuracy'], label='Train Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].legend(loc='upper left')

# Plot training & validation loss values
axs[1].plot(history.history['loss'], label='Train Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_title('Model Loss')
axs[1].legend(loc='upper left')


plt.tight_layout()
plt.show()

# %%
# Make predictions
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# Plot predicted vs actual
num_images = 15 # Number of images to display
fig, axs = plt.subplots(2, num_images, figsize=(20, 5))

for i in range(num_images):
    # Show the actual image
    axs[0, i].imshow(x_test[i], cmap='gray')
    axs[0, i].axis('off')
    axs[0, i].set_title(f"Actual: {y_test[i]}")
    
    # Show the predicted image
    axs[1, i].imshow(x_test[i], cmap='gray')
    axs[1, i].axis('off')
    axs[1, i].set_title(f"Predicted: {np.argmax(predictions[i])}")

plt.show()

print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_acc}")
# Out:
# Test loss: 0.2418830543756485
# Test accuracy: 0.9397000074386597

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Define the true labels and predicted labels
true_labels = y_test
predicted_labels = np.argmax(predictions, axis=1)

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Visualize the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
